# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
import time
from os import listdir

# %matplotlib inline

# %%
def crop_brain_contour(image, plot=False):

    import imutils
    import cv2
    from matplotlib import pyplot as plt

    # Convert the image to grayscale, and blur it slightly
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Threshold the image, then perform a series of erosions +
    # dilations to remove any small regions of noise
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)


    # Find the extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])

    # crop new image out of the original image using the four extreme points (left, right, top, bottom)
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]

    if plot:
        plt.figure()

        plt.subplot(1, 2, 1)
        plt.imshow(image)

        plt.tick_params(axis='both', which='both',
                        top=False, bottom=False, left=False, right=False,
                        labelbottom=False, labeltop=False, labelleft=False, labelright=False)

        plt.title('Original Image')

        plt.subplot(1, 2, 2)
        plt.imshow(new_image)

        plt.tick_params(axis='both', which='both',
                        top=False, bottom=False, left=False, right=False,
                        labelbottom=False, labeltop=False, labelleft=False, labelright=False)

        plt.title('Cropped Image')

        plt.show()

    return new_image

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (0.5.4)

# %%
ex_img = cv2.imread('brain_tumor_dataset/yes/Y1.jpg')
ex_new_img = crop_brain_contour(ex_img, True)

# %%
import os
import numpy as np
import cv2
from sklearn.utils import shuffle

def load_data(dir_list, image_size):
    """
    Read images, resize and normalize them. 
    Arguments:
        dir_list: list of strings representing file directories.
    Returns:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    """
    X = []
    y = []
    image_width, image_height = image_size

    for directory in dir_list:
        for filename in os.listdir(directory):
            image_path = os.path.join(directory, filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Warning: Failed to read image: {image_path}")
                continue

            # crop the brain and ignore unnecessary parts
            image = crop_brain_contour(image, plot=False)

            image = cv2.resize(image, dsize=(image_width, image_height), interpolation=cv2.INTER_CUBIC)
            image = image.astype(np.float32) / 255.0
            X.append(image)

            if 'yes' in directory.lower():
                y.append([1])
            else:
                y.append([0])

    X = np.array(X)
    y = np.array(y)

    X, y = shuffle(X, y)

    print(f'Number of examples is: {len(X)}')
    print(f'X shape is: {X.shape}')
    print(f'y shape is: {y.shape}')

    return X, y

# %%
augmented_path = 'Augmented_data/'

# augmented data (yes and no) contains both the original and the new generated examples
augmented_yes = 'Augmented_data/yes' 
augmented_no = 'Augmented_data/no'

IMG_WIDTH, IMG_HEIGHT = (128, 128)

X, y = load_data([augmented_yes, augmented_no], (IMG_WIDTH, IMG_HEIGHT))
# Out:
# Number of examples is: 1808
# X shape is: (1808, 128, 128, 3)
# y shape is: (1808, 1)

# %%
def plot_sample_images(X, y, n=10):
    """
    Plots n sample images for both values of y (labels).
    Arguments:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    """
    
    for label in [0,1]:
        # grab the first n images with the corresponding y values equal to label
        images = X[np.argwhere(y == label)]
        n_images = images[:n]
        
        columns_n = 10
        rows_n = int(n/ columns_n)

        plt.figure(figsize=(20, 10))
        
        i = 1 # current plot        
        for image in n_images:
            plt.subplot(rows_n, columns_n, i)
            plt.imshow(image[0])
            
            # remove ticks
            plt.tick_params(axis='both', which='both', 
                            top=False, bottom=False, left=False, right=False,
                           labelbottom=False, labeltop=False, labelleft=False, labelright=False)
            
            i += 1
        
        label_to_str = lambda label: "Yes" if label == 1 else "No"
        plt.suptitle(f"Brain Tumor: {label_to_str(label)}")
        plt.show()

# %%
plot_sample_images(X, y)

# %%
def split_data(X, y, test_size=0.2):
       
    """
    Splits data into training, development and test sets.
    Arguments:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    Returns:
        X_train: A numpy array with shape = (#_train_examples, image_width, image_height, #_channels)
        y_train: A numpy array with shape = (#_train_examples, 1)
        X_val: A numpy array with shape = (#_val_examples, image_width, image_height, #_channels)
        y_val: A numpy array with shape = (#_val_examples, 1)
        X_test: A numpy array with shape = (#_test_examples, image_width, image_height, #_channels)
        y_test: A numpy array with shape = (#_test_examples, 1)
    """
    
    X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=test_size)
    X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(X, y, test_size=0.3)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of development examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(y_train.shape))
print ("X_val (dev) shape: " + str(X_val.shape))
print ("Y_val (dev) shape: " + str(y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(y_test.shape))
# Out:
# number of training examples = 1265
# number of development examples = 272
# number of test examples = 271
# X_train shape: (1265, 128, 128, 3)
# Y_train shape: (1265, 1)
# X_val (dev) shape: (272, 128, 128, 3)
# Y_val (dev) shape: (272, 1)
# X_test shape: (271, 128, 128, 3)
# Y_test shape: (271, 1)

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return f"{h}:{m}:{round(s,1)}"

# %%
def compute_f1_score(y_true, prob):
    # convert the vector of probabilities to a target vector
    y_pred = np.where(prob > 0.5, 1, 0)
    
    score = f1_score(y_true, y_pred)
    
    return score

# %%
def build_model(input_shape):
    """
    Arugments:
        input_shape: A tuple representing the shape of the input of the model. shape=(image_width, image_height, #_channels)
    Returns:
        model: A Model object.
    """
    # Define the input placeholder as a tensor with shape input_shape. 
    X_input = Input(input_shape) # shape=(?, 240, 240, 3)
    
    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((2, 2))(X_input) # shape=(?, 244, 244, 3)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) # shape=(?, 238, 238, 32)
    
    # MAXPOOL
    X = MaxPooling2D((4, 4), name='max_pool0')(X) # shape=(?, 59, 59, 32) 
    
    # MAXPOOL
    X = MaxPooling2D((4, 4), name='max_pool1')(X) # shape=(?, 14, 14, 32)
    
    # FLATTEN X 
    X = Flatten()(X) # shape=(?, 6272)
    # FULLYCONNECTED
    X = Dense(1, activation='sigmoid', name='fc')(X) # shape=(?, 1)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='BrainDetectionModel')
    
    return model

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)

# %%
model = build_model(IMG_SHAPE)

# %%
model.summary()
# Out:
# Model: "BrainDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ zero_padding2d (ZeroPadding2D)       │ (None, 132, 132, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv0 (Conv2D)                       │ (None, 126, 126, 32)        │           4,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bn0 (BatchNormalization)             │ (None, 126, 126, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 126, 126, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pool0 (MaxPooling2D)             │ (None, 31, 31, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pool1 (MaxPooling2D)             │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1568)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc (Dense)                           │ (None, 1)                   │           1,569 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,433 (25.13 KB)
#  Trainable params: 6,369 (24.88 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# tensorboard
log_file_name = f'brain_tumor_detection_cnn_{int(time.time())}'
tensorboard = TensorBoard(log_dir=f'logs/{log_file_name}')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import os

# Ensure the models directory exists
os.makedirs("models", exist_ok=True)

# Save as `.keras` format
filepath = "cnn-parameters-improvement-{epoch:02d}-{val_accuracy:.2f}.keras"

checkpoint = ModelCheckpoint(
    filepath=os.path.join("models", filepath),
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=10, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6479 - loss: 0.6849
# Epoch 1: val_accuracy improved from -inf to 0.58456, saving model to models\cnn-parameters-improvement-01-0.58.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 296ms/step - accuracy: 0.6491 - loss: 0.6822 - val_accuracy: 0.5846 - val_loss: 0.6561
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.8188 - loss: 0.4130
# Epoch 2: val_accuracy did not improve from 0.58456
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 0.8190 - loss: 0.4127 - val_accuracy: 0.5000 - val_loss: 0.6868
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.8448 - loss: 0.3458
# Epoch 3: val_accuracy improved from 0.58456 to 0.68382, saving model to models\cnn-parameters-improvement-03-0.68.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 0.8453 - loss: 0.3452 - val_accuracy: 0.6838 - val_loss: 0.5863
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8951 - loss: 0.2753
# Epoch 4: val_accuracy did not improve from 0.68382
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 333ms/step - accuracy: 0.8951 - loss: 0.2752 - val_accuracy: 0.6434 - val_loss: 0.5741
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9330 - loss: 0.2281
# Epoch 5: val_accuracy improved from 0.68382 to 0.85294, saving model to models\cnn-parameters-improvement-05-0.85.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 350ms/step - accuracy: 0.9329 - loss: 0.2282 - val_accuracy: 0.8529 - val_loss: 0.4903
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9219 - loss: 0.2225
# Epoch 6: val_accuracy improved from 0.85294 to 0.86029, saving model to models\cnn-parameters-improvement-06-0.86.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 335ms/step - accuracy: 0.9220 - loss: 0.2224 - val_accuracy: 0.8603 - val_loss: 0.4492
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9506 - loss: 0.1850
# Epoch 7: val_accuracy improved from 0.86029 to 0.88971, saving model to models\cnn-parameters-improvement-07-0.89.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 335ms/step - accuracy: 0.9505 - loss: 0.1850 - val_accuracy: 0.8897 - val_loss: 0.4004
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9433 - loss: 0.1929
# Epoch 8: val_accuracy did not improve from 0.88971
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 337ms/step - accuracy: 0.9433 - loss: 0.1928 - val_accuracy: 0.8676 - val_loss: 0.3783
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9415 - loss: 0.1794
# Epoch 9: val_accuracy did not improve from 0.88971
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9418 - loss: 0.1792 - val_accuracy: 0.8860 - val_loss: 0.3294
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9611 - loss: 0.1546
# Epoch 10: val_accuracy improved from 0.88971 to 0.90074, saving model to models\cnn-parameters-improvement-10-0.90.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 328ms/step - accuracy: 0.9610 - loss: 0.1547 - val_accuracy: 0.9007 - val_loss: 0.2993
# Elapsed time: 0:2:11.6

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=3, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9794 - loss: 0.1222
# Epoch 1: val_accuracy did not improve from 0.90074
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9793 - loss: 0.1222 - val_accuracy: 0.8934 - val_loss: 0.2905
# Epoch 2/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9696 - loss: 0.1288
# Epoch 2: val_accuracy improved from 0.90074 to 0.90441, saving model to models\cnn-parameters-improvement-02-0.90.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 326ms/step - accuracy: 0.9697 - loss: 0.1287 - val_accuracy: 0.9044 - val_loss: 0.2674
# Epoch 3/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9783 - loss: 0.1157
# Epoch 3: val_accuracy improved from 0.90441 to 0.91544, saving model to models\cnn-parameters-improvement-03-0.92.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 335ms/step - accuracy: 0.9781 - loss: 0.1161 - val_accuracy: 0.9154 - val_loss: 0.2507
# Elapsed time: 0:0:39.7

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=3, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9663 - loss: 0.1267
# Epoch 1: val_accuracy did not improve from 0.91544
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 348ms/step - accuracy: 0.9663 - loss: 0.1268 - val_accuracy: 0.9007 - val_loss: 0.2506
# Epoch 2/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9794 - loss: 0.1069
# Epoch 2: val_accuracy did not improve from 0.91544
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 332ms/step - accuracy: 0.9791 - loss: 0.1072 - val_accuracy: 0.8382 - val_loss: 0.3689
# Epoch 3/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9869 - loss: 0.1014
# Epoch 3: val_accuracy did not improve from 0.91544
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 322ms/step - accuracy: 0.9869 - loss: 0.1014 - val_accuracy: 0.9118 - val_loss: 0.2500
# Elapsed time: 0:0:40.4

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=3, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9522 - loss: 0.1199
# Epoch 1: val_accuracy improved from 0.91544 to 0.91912, saving model to models\cnn-parameters-improvement-01-0.92.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 327ms/step - accuracy: 0.9527 - loss: 0.1195 - val_accuracy: 0.9191 - val_loss: 0.2237
# Epoch 2/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9859 - loss: 0.0798
# Epoch 2: val_accuracy improved from 0.91912 to 0.93015, saving model to models\cnn-parameters-improvement-02-0.93.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9860 - loss: 0.0799 - val_accuracy: 0.9301 - val_loss: 0.2186
# Epoch 3/3
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9873 - loss: 0.0754
# Epoch 3: val_accuracy did not improve from 0.93015
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.9873 - loss: 0.0755 - val_accuracy: 0.8529 - val_loss: 0.3082
# Elapsed time: 0:0:39.3

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=5, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9822 - loss: 0.0843
# Epoch 1: val_accuracy did not improve from 0.93015
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 326ms/step - accuracy: 0.9822 - loss: 0.0841 - val_accuracy: 0.8346 - val_loss: 0.3580
# Epoch 2/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9923 - loss: 0.0666
# Epoch 2: val_accuracy improved from 0.93015 to 0.93750, saving model to models\cnn-parameters-improvement-02-0.94.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 323ms/step - accuracy: 0.9923 - loss: 0.0666 - val_accuracy: 0.9375 - val_loss: 0.1853
# Epoch 3/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9962 - loss: 0.0505
# Epoch 3: val_accuracy did not improve from 0.93750
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 333ms/step - accuracy: 0.9962 - loss: 0.0506 - val_accuracy: 0.9228 - val_loss: 0.2125
# Epoch 4/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9963 - loss: 0.0538
# Epoch 4: val_accuracy did not improve from 0.93750
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 346ms/step - accuracy: 0.9963 - loss: 0.0538 - val_accuracy: 0.9375 - val_loss: 0.1956
# Epoch 5/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9992 - loss: 0.0527
# Epoch 5: val_accuracy did not improve from 0.93750
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 330ms/step - accuracy: 0.9991 - loss: 0.0527 - val_accuracy: 0.9265 - val_loss: 0.2089
# Elapsed time: 0:1:6.7

# %%
history = model.history.history

# %%
for key in history.keys():
    print(key)
# Out:
# accuracy
# loss
# val_accuracy
# val_loss

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

# %%
plot_metrics(history)

# %%
best_model = load_model(filepath='models/cnn-parameters-improvement-03-0.94.keras')

# %%
best_model.save('models/best_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss, acc = best_model.evaluate(x=X_test, y=y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9826 - loss: 0.0881

# %%
print (f"Test Loss = {loss}")
print (f"Test Accuracy = {acc}")
# Out:
# Test Loss = 0.08514311909675598
# Test Accuracy = 0.9815497994422913

# %%
y_test_prob = best_model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step

# %%
f1score = compute_f1_score(y_test, y_test_prob)
print(f"F1 score: {f1score}")
# Out:
# F1 score: 0.9825783972125436

# %%
y_val_prob = best_model.predict(X_val)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step

# %%
f1score_val = compute_f1_score(y_val, y_val_prob)
print(f"F1 score: {f1score_val}")
# Out:
# F1 score: 0.9818181818181818

# %%
def data_percentage(y):
    
    m=len(y)
    n_positive = np.sum(y)
    n_negative = m - n_positive
    
    pos_prec = (n_positive* 100.0)/ m
    neg_prec = (n_negative* 100.0)/ m
    
    print(f"Number of examples: {m}")
    print(f"Percentage of positive examples: {pos_prec}%, number of pos examples: {n_positive}") 
    print(f"Percentage of negative examples: {neg_prec}%, number of neg examples: {n_negative}")

# %%
data_percentage(y)
# Out:
# Number of examples: 1808
# Percentage of positive examples: 51.27212389380531%, number of pos examples: 927
# Percentage of negative examples: 48.72787610619469%, number of neg examples: 881

# %%
print("Training Data:")
data_percentage(y_train)
print("Validation Data:")
data_percentage(y_val)
print("Testing Data:")
data_percentage(y_test)
# Out:
# Training Data:
# Number of examples: 1265
# Percentage of positive examples: 51.30434782608695%, number of pos examples: 649
# Percentage of negative examples: 48.69565217391305%, number of neg examples: 616
# Validation Data:
# Number of examples: 272
# Percentage of positive examples: 50.0%, number of pos examples: 136
# Percentage of negative examples: 50.0%, number of neg examples: 136
# Testing Data:
# Number of examples: 271
# Percentage of positive examples: 52.398523985239855%, number of pos examples: 142
# Percentage of negative examples: 47.601476014760145%, number of neg examples: 129

# %%
# Predict probabilities
y_test_prob = best_model.predict(X_test)

# Convert probabilities to binary class labels using threshold 0.5
y_test_pred = (y_test_prob > 0.5).astype(int)

# Print classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_pred, target_names=['No Tumor', 'Tumor Detected']))

# Print each probability with its corresponding label
for prob in y_test_prob:
    label = "Tumor Detected" if prob > 0.5 else "No Tumor"
    print(f"Probability: {prob[0]:.4f} → {label}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
#                 precision    recall  f1-score   support
#
#       No Tumor       0.99      0.97      0.98       129
# Tumor Detected       0.97      0.99      0.98       142
#
#       accuracy                           0.98       271
#      macro avg       0.98      0.98      0.98       271
#   weighted avg       0.98      0.98      0.98       271
#
# Probability: 0.0000 → No Tumor
# Probability: 0.0131 → No Tumor
# Probability: 0.0741 → No Tumor
# Probability: 0.0125 → No Tumor
# Probability: 0.9974 → Tumor Detected
# Probability: 0.9978 → Tumor Detected
# Probability: 0.0127 → No Tumor
# Probability: 0.0576 → No Tumor
# Probability: 0.9669 → Tumor Detected
# Probability: 0.2870 → No Tumor
# Probability: 0.0458 → No Tumor
# Probability: 0.9967 → Tumor Detected
# Probability: 0.9918 → Tumor Detected
# Probability: 0.9676 → Tumor Detected
# Probability: 0.9996 → Tumor Detected
# Probability: 0.9922 → Tumor Detected
# Probability: 0.1196 → No Tumor
# Probability: 0.1703 → No Tumor
# Probability: 0.5558 → Tumor Detected
# Probability: 0.3764 → No Tumor
# Probability: 0.0466 → No Tumor
# Probability: 0.9997 → Tumor Detected
# Probability: 0.8658 → Tumor Detected
# Probability: 0.1089 → No Tumor
# Probability: 0.1037 → No Tumor
# Probability: 0.9817 → Tumor Detected
# Probability: 0.9874 → Tumor Detected
# Probability: 0.9928 → Tumor Detected
# Probability: 0.0203 → No Tumor
# Probability: 0.0013 → No Tumor
# Probability: 0.9989 → Tumor Detected
# Probability: 0.0564 → No Tumor
# Probability: 0.2399 → No Tumor
# Probability: 0.9582 → Tumor Detected
# Probability: 0.9996 → Tumor Detected
# Probability: 0.9980 → Tumor Detected
# Probability: 0.0031 → No Tumor
# Probability: 0.7650 → Tumor Detected
# Probability: 0.9996 → Tumor Detected
# Probability: 0.9953 → Tumor Detected
# Probability: 0.0237 → No Tumor
# Probability: 0.5338 → Tumor Detected
# Probability: 0.9992 → Tumor Detected
# Probability: 0.9860 → Tumor Detected
# Probability: 0.9382 → Tumor Detected
# Probability: 0.0056 → No Tumor
# Probability: 0.0285 → No Tumor
# Probability: 0.7766 → Tumor Detected
# Probability: 0.8992 → Tumor Detected
# Probability: 0.9455 → Tumor Detected
# Probability: 0.9221 → Tumor Detected
# Probability: 0.0025 → No Tumor
# Probability: 0.0406 → No Tumor
# Probability: 0.9972 → Tumor Detected
# Probability: 0.9936 → Tumor Detected
# Probability: 0.9753 → Tumor Detected
# Probability: 0.9724 → Tumor Detected
# Probability: 0.0898 → No Tumor
# Probability: 0.9877 → Tumor Detected
# Probability: 0.2720 → No Tumor
# Probability: 0.4466 → No Tumor
# Probability: 0.9982 → Tumor Detected
# Probability: 0.9459 → Tumor Detected
# Probability: 0.9737 → Tumor Detected
# Probability: 0.9467 → Tumor Detected
# Probability: 0.0264 → No Tumor
# Probability: 0.3347 → No Tumor
# Probability: 0.5377 → Tumor Detected
# Probability: 0.9976 → Tumor Detected
# Probability: 0.9935 → Tumor Detected
# Probability: 0.8295 → Tumor Detected
# Probability: 0.0144 → No Tumor
# Probability: 0.9991 → Tumor Detected
# Probability: 0.0002 → No Tumor
# Probability: 0.0110 → No Tumor
# Probability: 0.2567 → No Tumor
# Probability: 0.0558 → No Tumor
# Probability: 0.0011 → No Tumor
# Probability: 0.0142 → No Tumor
# Probability: 0.1180 → No Tumor
# Probability: 0.9999 → Tumor Detected
# Probability: 0.9963 → Tumor Detected
# Probability: 0.0018 → No Tumor
# Probability: 0.9935 → Tumor Detected
# Probability: 0.9920 → Tumor Detected
# Probability: 0.9999 → Tumor Detected
# Probability: 0.9738 → Tumor Detected
# Probability: 0.9952 → Tumor Detected
# Probability: 0.9766 → Tumor Detected
# Probability: 0.2355 → No Tumor
# Probability: 0.9985 → Tumor Detected
# Probability: 0.9617 → Tumor Detected
# Probability: 0.1565 → No Tumor
# Probability: 0.9970 → Tumor Detected
# Probability: 0.9255 → Tumor Detected
# Probability: 0.9408 → Tumor Detected
# Probability: 0.3357 → No Tumor
# Probability: 0.9780 → Tumor Detected
# Probability: 0.9993 → Tumor Detected
# Probability: 0.0815 → No Tumor
# Probability: 0.0340 → No Tumor
# Probability: 0.1975 → No Tumor
# Probability: 0.0006 → No Tumor
# Probability: 0.9895 → Tumor Detected
# Probability: 0.0151 → No Tumor
# Probability: 0.9985 → Tumor Detected
# Probability: 0.9879 → Tumor Detected
# Probability: 0.0018 → No Tumor
# Probability: 0.9860 → Tumor Detected
# Probability: 0.3797 → No Tumor
# Probability: 0.9788 → Tumor Detected
# Probability: 0.0140 → No Tumor
# Probability: 0.9938 → Tumor Detected
# Probability: 0.0137 → No Tumor
# Probability: 0.2834 → No Tumor
# Probability: 0.5616 → Tumor Detected
# Probability: 0.9945 → Tumor Detected
# Probability: 0.9976 → Tumor Detected
# Probability: 0.9643 → Tumor Detected
# Probability: 0.9934 → Tumor Detected
# Probability: 0.0007 → No Tumor
# Probability: 0.9726 → Tumor Detected
# Probability: 0.9983 → Tumor Detected
# Probability: 0.9958 → Tumor Detected
# Probability: 0.9989 → Tumor Detected
# Probability: 0.9408 → Tumor Detected
# Probability: 0.0795 → No Tumor
# Probability: 0.0229 → No Tumor
# Probability: 0.0629 → No Tumor
# Probability: 0.9942 → Tumor Detected
# Probability: 0.0103 → No Tumor
# Probability: 0.0100 → No Tumor
# Probability: 0.0634 → No Tumor
# Probability: 0.1318 → No Tumor
# Probability: 0.0266 → No Tumor
# Probability: 0.5407 → Tumor Detected
# Probability: 0.0060 → No Tumor
# Probability: 0.2973 → No Tumor
# Probability: 1.0000 → Tumor Detected
# Probability: 0.9567 → Tumor Detected
# Probability: 0.9012 → Tumor Detected
# Probability: 0.0195 → No Tumor
# Probability: 0.0933 → No Tumor
# Probability: 0.9856 → Tumor Detected
# Probability: 0.0382 → No Tumor
# Probability: 0.9977 → Tumor Detected
# Probability: 0.0014 → No Tumor
# Probability: 0.3263 → No Tumor
# Probability: 0.9224 → Tumor Detected
# Probability: 0.0392 → No Tumor
# Probability: 0.9344 → Tumor Detected
# Probability: 0.7728 → Tumor Detected
# Probability: 0.0008 → No Tumor
# Probability: 0.9036 → Tumor Detected
# Probability: 0.0032 → No Tumor
# Probability: 0.0138 → No Tumor
# Probability: 0.8400 → Tumor Detected
# Probability: 0.0272 → No Tumor
# Probability: 0.9410 → Tumor Detected
# Probability: 0.9841 → Tumor Detected
# Probability: 0.9306 → Tumor Detected
# Probability: 0.1785 → No Tumor
# Probability: 0.1076 → No Tumor
# Probability: 0.9974 → Tumor Detected
# Probability: 0.1492 → No Tumor
# Probability: 0.9545 → Tumor Detected
# Probability: 0.9266 → Tumor Detected
# Probability: 0.9437 → Tumor Detected
# Probability: 0.1965 → No Tumor
# Probability: 0.9971 → Tumor Detected
# Probability: 0.9918 → Tumor Detected
# Probability: 0.9957 → Tumor Detected
# Probability: 0.9766 → Tumor Detected
# Probability: 0.0478 → No Tumor
# Probability: 0.0759 → No Tumor
# Probability: 0.9964 → Tumor Detected
# Probability: 0.0008 → No Tumor
# Probability: 0.0241 → No Tumor
# Probability: 0.9653 → Tumor Detected
# Probability: 0.9979 → Tumor Detected
# Probability: 0.0133 → No Tumor
# Probability: 0.1181 → No Tumor
# Probability: 0.0103 → No Tumor
# Probability: 0.1338 → No Tumor
# Probability: 0.0227 → No Tumor
# Probability: 0.7894 → Tumor Detected
# Probability: 0.9847 → Tumor Detected
# Probability: 0.9765 → Tumor Detected
# Probability: 0.9994 → Tumor Detected
# Probability: 0.0130 → No Tumor
# Probability: 0.5015 → Tumor Detected
# Probability: 0.9913 → Tumor Detected
# Probability: 0.9668 → Tumor Detected
# Probability: 0.9965 → Tumor Detected
# Probability: 0.0131 → No Tumor
# Probability: 0.9997 → Tumor Detected
# Probability: 0.9769 → Tumor Detected
# Probability: 0.0012 → No Tumor
# Probability: 0.0649 → No Tumor
# Probability: 0.8547 → Tumor Detected
# Probability: 0.0056 → No Tumor
# Probability: 0.0465 → No Tumor
# Probability: 0.9956 → Tumor Detected
# Probability: 0.0317 → No Tumor
# Probability: 0.0910 → No Tumor
# Probability: 0.9859 → Tumor Detected
# Probability: 0.0202 → No Tumor
# Probability: 0.9443 → Tumor Detected
# Probability: 0.0453 → No Tumor
# Probability: 0.9296 → Tumor Detected
# Probability: 0.5871 → Tumor Detected
# Probability: 0.0581 → No Tumor
# Probability: 0.0004 → No Tumor
# Probability: 0.1088 → No Tumor
# Probability: 0.0933 → No Tumor
# Probability: 0.9965 → Tumor Detected
# Probability: 0.9996 → Tumor Detected
# Probability: 0.0026 → No Tumor
# Probability: 0.9968 → Tumor Detected
# Probability: 0.8517 → Tumor Detected
# Probability: 0.9697 → Tumor Detected
# Probability: 0.4381 → No Tumor
# Probability: 0.9494 → Tumor Detected
# Probability: 0.0184 → No Tumor
# Probability: 0.9487 → Tumor Detected
# Probability: 0.0510 → No Tumor
# Probability: 0.0027 → No Tumor
# Probability: 0.9993 → Tumor Detected
# Probability: 0.0145 → No Tumor
# Probability: 0.0373 → No Tumor
# Probability: 0.0502 → No Tumor
# Probability: 0.9996 → Tumor Detected
# Probability: 0.2073 → No Tumor
# Probability: 0.0064 → No Tumor
# Probability: 0.9724 → Tumor Detected
# Probability: 0.2117 → No Tumor
# Probability: 0.9979 → Tumor Detected
# Probability: 0.9975 → Tumor Detected
# Probability: 0.0051 → No Tumor
# Probability: 0.1458 → No Tumor
# Probability: 0.0069 → No Tumor
# Probability: 0.9976 → Tumor Detected
# Probability: 0.9953 → Tumor Detected
# Probability: 0.8013 → Tumor Detected
# Probability: 0.0221 → No Tumor
# Probability: 0.9969 → Tumor Detected
# Probability: 0.0307 → No Tumor
# Probability: 0.0546 → No Tumor
# Probability: 0.0909 → No Tumor
# Probability: 0.9992 → Tumor Detected
# Probability: 0.9822 → Tumor Detected
# Probability: 0.9996 → Tumor Detected
# Probability: 0.0214 → No Tumor
# Probability: 0.9964 → Tumor Detected
# Probability: 0.1873 → No Tumor
# Probability: 0.9189 → Tumor Detected
# Probability: 0.0071 → No Tumor
# Probability: 0.0975 → No Tumor
# Probability: 0.9763 → Tumor Detected
# Probability: 0.9966 → Tumor Detected
# Probability: 0.9918 → Tumor Detected
# Probability: 0.9866 → Tumor Detected
# Probability: 0.9800 → Tumor Detected
# Probability: 0.9975 → Tumor Detected
# Probability: 0.0152 → No Tumor
# Probability: 0.0363 → No Tumor
# Probability: 0.2022 → No Tumor
# Probability: 0.1499 → No Tumor
# Probability: 0.0431 → No Tumor
# Probability: 0.9968 → Tumor Detected
# Probability: 0.5782 → Tumor Detected

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load model for Flask use
model = load_model("models/best_model.h5")

# Image Preprocessing
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.0
    img = np.expand_dims(img, axis=0)
    return img

# Tumor Prediction
def predict_tumor(image_path):
    processed = preprocess_image(image_path)
    prob = model.predict(processed)[0][0]
    label = "Tumor Detected" if prob > 0.5 else "No Tumor"
    return label, float(prob)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
label, probability = predict_tumor("Sample_image.jpg")
print(f"Prediction: {label} with probability {probability:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Prediction: No Tumor with probability 0.0406
